# %%
with open('WhatsApp Chat with Aditya Gupta.txt') as rwdata:
    data = rwdata.read()
    data = data.rsplit("\n")
new=list()
for i in data:
    nl = i.split(" - ")
    new.append(nl)
for i in new:
   i.pop(0)
new
# Out:
# [['YOU: Kaha  hai ??'],
#  ['Aditya Gupta: Delhi..!!'],
#  ['YOU: 11 ko aane wala tha tu'],
#  ['YOU: 9 ka bol ke mujhe bula liya'],
#  ['Aditya Gupta: Tera roomie nhi aaya??'],
#  ['YOU: Usse kya frk padta hai, baat apne bich hui thi'],
#  ['YOU: Aane na aane ki'],
#  ['Aditya Gupta: Arre.. agr wo aaya hga..'],
#  ['YOU: Tene bola tha jaipur aaja, usne nhi'],
#  ['Aditya Gupta: Toh mereko toh jgah dhundhni pdegi na'],
#  ['YOU: Alag alag room hai'],
#  ['YOU: Ab'],
#  ['YOU: Or room khali hai mere yaha pg me'],
#  ['Aditya Gupta: Tu akela hai??'],
#  ['YOU: Abhi toh haa'],
#  ['YOU: Baaki nhi , vo niche hai'],
#  ['Aditya Gupta: 14-15 ko aaga hun'],
#  ['YOU: Aa hi mat'],
#  ['YOU: Dikh bhi mat'],
#  ['Aditya Gupta: Vcl kr'],
#  ['Aditya Gupta: Utha ke'],
#  ['YOU: No'],
#  ['Aditya Gupta: 😂'],
#  ['Aditya Gupta: Chl thk hai'],
#  ['YOU: Meri back clear kr di mene 2nd sem ki🙂'],
#  ['Aditya Gupta: 🤩🤩🤩💥💥'],
#  ['YOU: Tene padhaya tha❣️'],
#  ['YOU: 🙃'],
# ...

# %%
endstring = ' '
for s in new:
    for j in s:
        endstring += j
        endstring += "***"
endstring
n = endstring.rsplit("***YOU:")
fomList=list()
for i in n:
    nl = i.split("***Aditya Gupta:")
    fomList.append(nl)
fomList
# Out:
# [[' YOU: Kaha  hai ??', ' Delhi..!!'],
#  [' 11 ko aane wala tha tu'],
#  [' 9 ka bol ke mujhe bula liya', ' Tera roomie nhi aaya??'],
#  [' Usse kya frk padta hai, baat apne bich hui thi'],
#  [' Aane na aane ki', ' Arre.. agr wo aaya hga..'],
#  [' Tene bola tha jaipur aaja, usne nhi',
#   ' Toh mereko toh jgah dhundhni pdegi na'],
#  [' Alag alag room hai'],
#  [' Ab'],
#  [' Or room khali hai mere yaha pg me', ' Tu akela hai??'],
#  [' Abhi toh haa'],
#  [' Baaki nhi , vo niche hai', ' 14-15 ko aaga hun'],
#  [' Aa hi mat'],
#  [' Dikh bhi mat', ' Vcl kr', ' Utha ke'],
#  [' No', ' 😂', ' Chl thk hai'],
#  [' Meri back clear kr di mene 2nd sem ki🙂', ' 🤩🤩🤩💥💥'],
#  [' Tene padhaya tha❣️'],
#  [' 🙃', ' Kitne aaye the??'],
#  [' <Media omitted>'],
#  [' Jitne chahiye the uske almost double', ' 😂😂'],
#  [' Laga tha bas pas hounga, yaha umeed se jyada aagye'],
#  [' Bohot jyada 😂', ' Teri baat hit kr gyi mujhe'],
#  [' Bsdk mil toh sahi tu me bhi hit karunga', ' Parso aa rha hun'],
# ...

# %%
'''
new_format=[["SENT","RECEVIED"]]
for i in range(len(new)):
    if re.findall("\AYOU:", new[i][0]):
        new_format.append(new[i])
    elif re.findall("\AAditya Gupta:", new[i]):
'''
# Out:
# '\nnew_format=[["SENT","RECEVIED"]]\nfor i in range(len(new)):\n    if re.findall("\\AYOU:", new[i][0]):\n        new_format.append(new[i])\n    elif re.findall("\\AAditya Gupta:", new[i]):\n'
